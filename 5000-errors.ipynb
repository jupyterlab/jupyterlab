# %%
# Imagine this cell called a function which runs things on a cluster and you have an error
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-56e1109ae320> in <module>
# ----> 1 iAmNotDefined
#
# NameError: name 'iAmNotDefined' is not defined
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-56e1109ae320> in <module>
# ----> 1 iAmNotDefined
#
# NameError: name 'iAmNotDefined' is not defined
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-56e1109ae320> in <module>
# ----> 1 iAmNotDefined
#
# NameError: name 'iAmNotDefined' is not defined
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ...
